# %%
import datetime
import math
import os
from os import path, replace
from pathlib import Path
import sys
from pprint import pprint

import random

import torch
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader, ConcatDataset
from torchvision import transforms
from torchvision.transforms import InterpolationMode
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt

# %%
import torch.distributed as distributed

distributed.init_process_group(backend='nccl', init_method='tcp://localhost:25763', rank=0, world_size=1)
print(f'CUDA Device count: {torch.cuda.device_count()}')

local_rank = torch.distributed.get_rank()
world_size = torch.distributed.get_world_size()
torch.cuda.set_device(local_rank)

print(f'I am rank {local_rank} in this world of size {world_size}!')
# Out:
# CUDA Device count: 1
# I am rank 0 in this world of size 1!

# %%
XMem_path = os.path.abspath('./XMem') # Parent folder /app/mount
sys.path.append(XMem_path)
# !wget -P ./XMem/saves/ https://github.com/hkchengrex/XMem/releases/download/v1.0/XMem.pth

# %%
from util.logger import TensorboardLogger

from model.trainer import XMemTrainer

# %%
torch.backends.cudnn.benchmark = True

# %%
im_mean = (124, 116, 104)

im_normalization = transforms.Normalize(
                    mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225]
                )

inv_im_trans = transforms.Normalize(
                mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
                std=[1/0.229, 1/0.224, 1/0.225])

# %%
def reseed(seed):
    random.seed(seed)
    torch.manual_seed(seed)

# %%
def plotDatasetSample(dataset, rows):
    first_seq = dataset[0]
    print('rgb', first_seq['rgb'].shape)
    print('first_frame_gt', first_seq['first_frame_gt'].shape)
    print('cls_gt', first_seq['cls_gt'].shape)
    print('selector', first_seq['selector'])
    print('info', first_seq['info'])

    cols = 2
    fig, axes = plt.subplots(rows, cols, figsize=(10, 15))
    
    for i in range(rows):
        # Plot RGB image
        rgb_image = inv_im_trans(first_seq['rgb'][i]).permute(1,2,0).numpy()
        axes[i, 0].imshow(rgb_image)
        axes[i, 0].axis('off')
        
        # Plot binary mask
        mask = first_seq['cls_gt'][i][0]
        axes[i, 1].imshow(mask, cmap='gray')
        axes[i, 1].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
class BinaryInstrumentDataset(Dataset):
    """
    Works for DAVIS/YouTubeVOS/BL30K training
    For each sequence:
    - Pick three frames
    - Pick two objects
    - Apply some random transforms that are the same for all frames
    - Apply random transform to each of the frame
    - The distance between frames is controlled
    """
    def __init__(self, im_root, gt_root, max_jump, subset=None, num_frames=3, max_num_obj=1, finetune=False):
        
        self.im_root = im_root # Root directory for Images
        self.gt_root = gt_root # Root directory for ground truth data
        self.max_jump = max_jump # Maximum distance between frames
        # self.is_bl = is_bl # Is it a blender dataset
        self.num_frames = num_frames # Number of frames to be sampled
        self.max_num_obj = max_num_obj # Maximum number of objects

        # Initialize lists for storing video and frame information
        self.videos = [] # List of videos
        self.frames = {} # Dictionary mapping video to its frames

        vid_list = sorted(os.listdir(self.im_root))
        # Pre-filtering
        for vid in vid_list:
            # If looking for a subset of videos only
            if subset is not None:
                vid_name = vid
                if vid_name not in subset:
                    continue
            
            # List frames in each video directory
            frames = sorted(os.listdir(os.path.join(self.im_root, vid)))
            
            if len(frames) < num_frames:
                continue
            self.frames[vid] = frames
            self.videos.append(vid)

        print('%d out of %d videos accepted in %s.' % (len(self.videos), len(vid_list), im_root))

        # These set of transform is the same for im/gt pairs, but different among the 3 sampled frames
        self.pair_im_lone_transform = transforms.Compose([
            transforms.ColorJitter(0.01, 0.01, 0.01, 0),
        ])

        self.pair_im_dual_transform = transforms.Compose([
            transforms.RandomAffine(degrees=0 if finetune else 15, shear=0 if finetune else 10, interpolation=InterpolationMode.BILINEAR, fill=im_mean),
        ])

        self.pair_gt_dual_transform = transforms.Compose([
            transforms.RandomAffine(degrees=0 if finetune else 15, shear=0 if finetune else 10, interpolation=InterpolationMode.NEAREST, fill=0),
        ])

        # These transform are the same for all pairs in the sampled sequence
        self.all_im_lone_transform = transforms.Compose([
            transforms.ColorJitter(0.1, 0.03, 0.03, 0),
            transforms.RandomGrayscale(0.05),
        ])

        self.all_im_dual_transform = transforms.Compose([
                transforms.RandomHorizontalFlip(),
                transforms.RandomResizedCrop((384, 384), scale=(0.36,1.00), interpolation=InterpolationMode.BILINEAR)
            ])

        self.all_gt_dual_transform = transforms.Compose([
                transforms.RandomHorizontalFlip(),
                transforms.RandomResizedCrop((384, 384), scale=(0.36,1.00), interpolation=InterpolationMode.NEAREST)
            ])

        # Final transform without randomness
        self.final_im_transform = transforms.Compose([
            transforms.ToTensor(),
            im_normalization,
        ])

    def __getitem__(self, idx):
        video = self.videos[idx]
        info = {}
        info['name'] = video

        vid_im_path = path.join(self.im_root, video)
        vid_gt_path = path.join(self.gt_root, video)
        frames = self.frames[video]

        trials = 0
        while trials < 5:
            info['frames'] = [] # Appended with actual frames

            num_frames = self.num_frames
            length = len(frames)
            this_max_jump = min(len(frames), self.max_jump)

            # iterative sampling
            frames_idx = [np.random.randint(length)]
            acceptable_set = set(range(max(0, frames_idx[-1]-this_max_jump), min(length, frames_idx[-1]+this_max_jump+1))).difference(set(frames_idx))
            while(len(frames_idx) < num_frames):
                idx = np.random.choice(list(acceptable_set))
                frames_idx.append(idx)
                new_set = set(range(max(0, frames_idx[-1]-this_max_jump), min(length, frames_idx[-1]+this_max_jump+1)))
                acceptable_set = acceptable_set.union(new_set).difference(set(frames_idx))

            frames_idx = sorted(frames_idx)
            if np.random.rand() < 0.5:
                # Reverse time
                frames_idx = frames_idx[::-1]

            sequence_seed = np.random.randint(2147483647)
            images = []
            masks = []
            target_objects = []
            for f_idx in frames_idx:
                jpg_name = frames[f_idx]
                png_name = frames[f_idx]
                info['frames'].append(jpg_name)

                reseed(sequence_seed)
                this_im = Image.open(path.join(vid_im_path, jpg_name)).convert('RGB')
                this_im = self.all_im_dual_transform(this_im)
                this_im = self.all_im_lone_transform(this_im)
                reseed(sequence_seed)
                this_gt = Image.open(path.join(vid_gt_path, png_name)).convert('P')
                this_gt = self.all_gt_dual_transform(this_gt)

                pairwise_seed = np.random.randint(2147483647)
                reseed(pairwise_seed)
                this_im = self.pair_im_dual_transform(this_im)
                this_im = self.pair_im_lone_transform(this_im)
                reseed(pairwise_seed)
                this_gt = self.pair_gt_dual_transform(this_gt)

                this_im = self.final_im_transform(this_im)
                this_gt = np.array(this_gt)

                images.append(this_im)
                masks.append(this_gt)

            images = torch.stack(images, 0)

            labels = np.unique(masks[0])
            # Remove background
            labels = labels[labels!=0]

            
            if len(labels) == 0:
                target_objects = []
                trials += 1
            else:
                target_objects = labels.tolist()
                break

        if len(target_objects) > self.max_num_obj:
            target_objects = np.random.choice(target_objects, size=self.max_num_obj, replace=False)

        info['num_objects'] = max(1, len(target_objects))

        masks = np.stack(masks, 0)

        # Generate one-hot ground-truth
        cls_gt = np.zeros((self.num_frames, 384, 384), dtype=np.int64)
        first_frame_gt = np.zeros((1, self.max_num_obj, 384, 384), dtype=np.int64)
        for i, l in enumerate(target_objects):
            this_mask = (masks==l)
            cls_gt[this_mask] = i+1
            first_frame_gt[0,i] = (this_mask[0])
        cls_gt = np.expand_dims(cls_gt, 1)

        # 1 if object exist, 0 otherwise
        selector = [1 if i < info['num_objects'] else 0 for i in range(self.max_num_obj)]
        selector = torch.FloatTensor(selector)

        data = {
            'rgb': images,
            'first_frame_gt': first_frame_gt,
            'cls_gt': cls_gt,
            'selector': selector,
            'info': info,
        }

        return data

    def __len__(self):
        return len(self.videos)

# %%
main_folder = Path("./data")
VIDEOS_PATH = main_folder/"endo17_binary"/"frames"
MASKS_PATH = main_folder/"endo17_binary"/"masks"

sample_dataset = BinaryInstrumentDataset(VIDEOS_PATH, MASKS_PATH, 
                              max_jump=20, subset=None, num_frames=8, 
                              max_num_obj=1, finetune=True
                              )
# Out:
# 18 out of 18 videos accepted in data/endo17_binary/frames.

# %%
plotDatasetSample(sample_dataset, 3)
# Out:
# rgb torch.Size([8, 3, 384, 384])
# first_frame_gt (1, 1, 384, 384)
# cls_gt (8, 1, 384, 384)
# selector tensor([1.])
# info {'name': 'instrument_dataset_01_test', 'frames': ['frame244.png', 'frame257.png', 'frame260.png', 'frame266.png', 'frame269.png', 'frame283.png', 'frame285.png', 'frame297.png'], 'num_objects': 1}

# %%
raw_config = {'benchmark': False,
 'bl_root': '../BL30K', 'davis_root': '../DAVIS',
 'debug': False,
 'deep_update_prob': 0.2,
 'exp_id': 'NULL',
 'gamma': 0.1,
 'hidden_dim': 64,
 'key_dim': 64,
 'load_checkpoint': None, 'load_network': None,
              
 'log_image_interval': 100, 'log_text_interval': 50,
 
 'no_amp': False,
 'num_workers': 0,

 # 's0_batch_size': 16, 's0_end_warm': 70000, 's0_finetune': 0, 's0_iterations': 150000, 's0_lr': 1e-05,
 #              's0_num_frames': 3, 's0_num_ref_frames': 2, 's0_start_warm': 20000, 's0_steps': [],
 # 's1_batch_size': 8, 's1_end_warm': 70000, 's1_finetune': 0, 's1_iterations': 250000, 's1_lr': 1e-05,
 #              's1_num_frames': 8, 's1_num_ref_frames': 3, 's1_start_warm': 20000, 's1_steps': [200000],
 # 's2_batch_size': 8, 's2_end_warm': 70000, 's2_finetune': 10000, 's2_iterations': 150000, 's2_lr': 1e-05,
 #              's2_num_frames': 8, 's2_num_ref_frames': 3, 's2_start_warm': 20000, 's2_steps': [120000],
 's3_batch_size': 8, 's3_end_warm': 700, 's3_finetune': 0, 's3_iterations': 3_000, 's3_lr': 1e-5,
              's3_num_frames': 16, 's3_num_ref_frames': 3, 's3_start_warm': 200, 's3_steps': [2400],

 'save_checkpoint_interval': 100, 'save_network_interval': 50,
 
 'stages': '3',
 
 'static_root': '../static',
 'value_dim': 512,
 'weight_decay': 0.05,
 'yv_root': '../YouTube'}

# %%
# Set seed to ensure the same initialization
torch.manual_seed(14159265)
np.random.seed(14159265)
random.seed(14159265)

stage = 's'+raw_config['stages'] if len(raw_config['stages']) == 1 else 3


config = {
            'batch_size': raw_config[stage+'_batch_size'],
            'iterations': raw_config[stage+'_iterations'],
            'finetune': raw_config[stage+'_finetune'],
            'steps': raw_config[stage+'_steps'],
            'lr': raw_config[stage+'_lr'],
            'num_ref_frames': raw_config[stage+'_num_ref_frames'],
            'num_frames': raw_config[stage+'_num_frames'],
            'start_warm': raw_config[stage+'_start_warm'],
            'end_warm': raw_config[stage+'_end_warm'],
        }

config['num_workers'] = raw_config['num_workers']

config['deep_update_prob'] = raw_config['deep_update_prob']
config['weight_decay'] = raw_config['weight_decay']
config['gamma'] = raw_config['gamma']
config['amp'] = not raw_config['no_amp']

config['log_text_interval'] = raw_config['log_text_interval']
config['log_image_interval'] = raw_config['log_image_interval']
config['save_network_interval'] = raw_config['save_network_interval']
config['save_checkpoint_interval'] = raw_config['save_checkpoint_interval']

config['debug'] = raw_config['debug']
config['exp_id'] = 'EndoVis17_Binary'

long_id = '%s_%s' % (datetime.datetime.now().strftime('%b%d_%H.%M.%S'), config['exp_id'])

git_info = 'XMem'
logger = TensorboardLogger(config['exp_id'], long_id, git_info)
logger.log_string('hyperpara', str(config))
# Out:
# git XMem
# hyperpara {'batch_size': 8, 'iterations': 3000, 'finetune': 0, 'steps': [2400], 'lr': 1e-05, 'num_ref_frames': 3, 'num_frames': 16, 'start_warm': 200, 'end_warm': 700, 'num_workers': 0, 'deep_update_prob': 0.2, 'weight_decay': 0.05, 'gamma': 0.1, 'amp': True, 'log_text_interval': 50, 'log_image_interval': 100, 'save_network_interval': 50, 'save_checkpoint_interval': 100, 'debug': False, 'exp_id': 'EndoVis17_Binary'}

# %%
model = XMemTrainer(config, logger=logger, 
                    save_path=path.join('saves', long_id, long_id) if long_id is not None else None, 
                    local_rank=0, world_size = 1).train()
model.load_network("./XMem/saves/XMem.pth")

total_iter = 0
# Out:
# key_dim not found in config. Set to default 64
# value_dim not found in config. Set to default 512
# hidden_dim not found in config. Set to default 64
# Single object mode: False
# model_size 62185224
# Network weight loaded from memory.
# Network weight loaded from ./XMem/saves/XMem.pth

# %%
def worker_init_fn(worker_id): 
        worker_seed = torch.initial_seed()%(2**31) + worker_id + local_rank*100
        np.random.seed(worker_seed)
        random.seed(worker_seed)

# %%
def renew_loader(video_path, masks_path, max_skip, subset=None, finetune=True):
    dataset = BinaryInstrumentDataset(video_path, masks_path, 
                                  max_jump=max_skip, subset=subset, 
                                  num_frames=config['num_frames'], 
                                  max_num_obj=1, finetune=finetune
                                  )
    
    train_sampler = torch.utils.data.distributed.DistributedSampler(dataset, rank=local_rank, shuffle=True)
    train_loader = DataLoader(dataset, config['batch_size'], sampler=train_sampler, 
                              num_workers=config['num_workers'], 
                              worker_init_fn=worker_init_fn, drop_last=True)

    return train_sampler, train_loader

# %% [markdown]
# ### Training on EndoVis 17 Data

# %%
MAX_SKIP_VALUES = [10, 15, 5, 5]

increase_skip_fraction = [0.1, 0.3, 0.9, 100]

train_subset = []
test_subset = []

for folder in VIDEOS_PATH.iterdir():
    if 'test' in folder.name:
        test_subset.append(folder.name)
    else:
        train_subset.append(folder.name)
        
train_sampler, train_loader = renew_loader(VIDEOS_PATH, MASKS_PATH, 20, subset = train_subset, finetune=False)
# Out:
# 8 out of 18 videos accepted in data/endo17_binary/frames.

# %%
total_epoch = math.ceil(config['iterations']/len(train_loader))
current_epoch = total_iter // len(train_loader)
print(f'Current epoch is {current_epoch}.')
print(f'We approximately use {total_epoch} epochs.')

change_skip_iter = [round(config['iterations']*f) for f in increase_skip_fraction]
# Skip will only change after an epoch, not in the middle
print(f'The skip value will change approximately at the following iterations: {change_skip_iter[:-1]}')
# Out:
# Current epoch is 0.
# We approximately use 3000 epochs.
# The skip value will change approximately at the following iterations: [300, 900, 2700]

# %%
finetuning = False
# Need this to select random bases in different workers
np.random.seed(np.random.randint(2**30-1) + local_rank*100)
try:
    while total_iter < config['iterations'] + config['finetune']:
        
        # Crucial for randomness! 
        train_sampler.set_epoch(current_epoch)
        current_epoch += 1
        print(f'Current epoch: {current_epoch}')

        # Train loop
        model.train()
        for data in train_loader:
            # Update skip if needed
            if stage!='0' and total_iter >= change_skip_iter[0]:
                while total_iter >= change_skip_iter[0]:
                    cur_skip = MAX_SKIP_VALUES[0]
                    max_skip_values = MAX_SKIP_VALUES[1:]
                    change_skip_iter = change_skip_iter[1:]
                print(f'Changing skip to {cur_skip=}')
                train_sampler, train_loader = renew_loader(VIDEOS_PATH, MASKS_PATH, cur_skip,
                                                           subset = train_subset, finetune=False)
                break

            # fine-tune means fewer augmentations to train the sensory memory
            if config['finetune'] > 0 and not finetuning and total_iter >= config['iterations']:
                train_sampler, train_loader = renew_loader(VIDEOS_PATH, MASKS_PATH, cur_skip,
                                                           subset = train_subset, finetune=True)
                finetuning = True
                model.save_network_interval = 50
                break

            model.do_pass(data, total_iter)
            total_iter += 1

            if total_iter >= config['iterations'] + config['finetune']:
                break
finally:
    if not config['debug'] and model.logger is not None and total_iter>5000:
        model.save_network(total_iter)
        model.save_checkpoint(total_iter)
# Out:
# Current epoch: 1
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Current epoch: 2
# Current epoch: 3
# Current epoch: 4
# Current epoch: 5
# Current epoch: 6
# Current epoch: 7
# Current epoch: 8
# Current epoch: 9
# Current epoch: 10
# Current epoch: 11
# Current epoch: 12
# Current epoch: 13
# Current epoch: 14
# Current epoch: 15
# Current epoch: 16
# Current epoch: 17
# Current epoch: 18
# Current epoch: 19
# Current epoch: 20
# Current epoch: 21
# Current epoch: 22
# Current epoch: 23
# Current epoch: 24
# Current epoch: 25
# Current epoch: 26
# Current epoch: 27
# Current epoch: 28
# Current epoch: 29
# Current epoch: 30
# Current epoch: 31
# Current epoch: 32
# Current epoch: 33
# Current epoch: 34
# Current epoch: 35
# Current epoch: 36
# Current epoch: 37
# Current epoch: 38
# Current epoch: 39
# Current epoch: 40
# Current epoch: 41
# Current epoch: 42
# Current epoch: 43
# Current epoch: 44
# Current epoch: 45
# Current epoch: 46
# Current epoch: 47
# Current epoch: 48
# Current epoch: 49
# Current epoch: 50
# Current epoch: 51
# EndoVis17_Binary - It     50 [TRAIN] [time         ]: 13.006444
# EndoVis17_Binary - It     50 [TRAIN] [total_loss   ]: 3.1091487
# EndoVis17_Binary - It     50 [TRAIN] [p            ]: 1.0000000
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_1    ]: 0.0548418
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_1  ]: 0.1166538
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_2    ]: 0.0624679
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_2  ]: 0.1196431
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_3    ]: 0.0643599
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_3  ]: 0.1255947
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_4    ]: 0.0666376
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_4  ]: 0.1284306
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_5    ]: 0.0639375
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_5  ]: 0.1223691
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_6    ]: 0.0703577
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_6  ]: 0.1224402
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_7    ]: 0.0676753
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_7  ]: 0.1364172
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_8    ]: 0.0654875
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_8  ]: 0.1303747
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_9    ]: 0.0694381
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_9  ]: 0.1434915
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_10   ]: 0.0761459
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_10 ]: 0.1422082
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_11   ]: 0.0733391
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_11 ]: 0.1480717
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_12   ]: 0.0739345
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_12 ]: 0.1458632
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_13   ]: 0.0765204
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_13 ]: 0.1552834
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_14   ]: 0.0841241
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_14 ]: 0.1641964
# EndoVis17_Binary - It     50 [TRAIN] [ce_loss_15   ]: 0.0763787
# EndoVis17_Binary - It     50 [TRAIN] [dice_loss_15 ]: 0.1624635
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_50.pth.
# Current epoch: 52
# Current epoch: 53
# Current epoch: 54
# Current epoch: 55
# Current epoch: 56
# Current epoch: 57
# Current epoch: 58
# Current epoch: 59
# Current epoch: 60
# Current epoch: 61
# Current epoch: 62
# Current epoch: 63
# Current epoch: 64
# Current epoch: 65
# Current epoch: 66
# Current epoch: 67
# Current epoch: 68
# Current epoch: 69
# Current epoch: 70
# Current epoch: 71
# Current epoch: 72
# Current epoch: 73
# Current epoch: 74
# Current epoch: 75
# Current epoch: 76
# Current epoch: 77
# Current epoch: 78
# Current epoch: 79
# Current epoch: 80
# Current epoch: 81
# Current epoch: 82
# Current epoch: 83
# Current epoch: 84
# Current epoch: 85
# Current epoch: 86
# Current epoch: 87
# Current epoch: 88
# Current epoch: 89
# Current epoch: 90
# Current epoch: 91
# Current epoch: 92
# Current epoch: 93
# Current epoch: 94
# Current epoch: 95
# Current epoch: 96
# Current epoch: 97
# Current epoch: 98
# Current epoch: 99
# Current epoch: 100
# Current epoch: 101
# EndoVis17_Binary - It    100 [TRAIN] [time         ]: 12.722957
# EndoVis17_Binary - It    100 [TRAIN] [total_loss   ]: 2.0015084
# EndoVis17_Binary - It    100 [TRAIN] [p            ]: 1.0000000
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_1    ]: 0.0410664
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_1  ]: 0.0884042
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_2    ]: 0.0429522
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_2  ]: 0.0697695
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_3    ]: 0.0446830
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_3  ]: 0.0823322
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_4    ]: 0.0449923
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_4  ]: 0.0884794
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_5    ]: 0.0439378
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_5  ]: 0.0780864
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_6    ]: 0.0389701
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_6  ]: 0.0719099
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_7    ]: 0.0444960
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_7  ]: 0.0864504
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_8    ]: 0.0499617
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_8  ]: 0.0861683
# EndoVis17_Binary - It    100 [TRAIN] [ce_loss_9    ]: 0.0437786
# EndoVis17_Binary - It    100 [TRAIN] [dice_loss_9  ]: 0.0836263
# EndoVis17_Binary - It    200 [TRAIN] [total_loss   ]: 1.7362991
# EndoVis17_Binary - It    200 [TRAIN] [p            ]: 1.0000000
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_1    ]: 0.0380262
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_1  ]: 0.0797877
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_2    ]: 0.0343661
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_2  ]: 0.0715923
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_3    ]: 0.0346174
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_3  ]: 0.0760582
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_4    ]: 0.0345366
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_4  ]: 0.0714548
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_5    ]: 0.0403671
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_5  ]: 0.0813223
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_6    ]: 0.0348517
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_6  ]: 0.0750003
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_7    ]: 0.0396149
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_7  ]: 0.0757415
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_8    ]: 0.0453180
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_8  ]: 0.0789286
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_9    ]: 0.0395477
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_9  ]: 0.0733494
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_10   ]: 0.0417247
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_10 ]: 0.0774841
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_11   ]: 0.0372538
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_11 ]: 0.0779625
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_12   ]: 0.0366841
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_12 ]: 0.0744689
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_13   ]: 0.0352288
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_13 ]: 0.0747188
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_14   ]: 0.0379447
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_14 ]: 0.0841527
# EndoVis17_Binary - It    200 [TRAIN] [ce_loss_15   ]: 0.0406391
# EndoVis17_Binary - It    200 [TRAIN] [dice_loss_15 ]: 0.0935548
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_200.pth.
# Checkpoint saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_checkpoint_200.pth.
# Current epoch: 202
# Current epoch: 203
# Current epoch: 204
# Current epoch: 205
# Current epoch: 206
# Current epoch: 207
# Current epoch: 208
# Current epoch: 209
# Current epoch: 210
# Current epoch: 211
# Current epoch: 212
# EndoVis17_Binary - It    250 [TRAIN] [dice_loss_13 ]: 0.0646425
# EndoVis17_Binary - It    250 [TRAIN] [ce_loss_14   ]: 0.0361115
# EndoVis17_Binary - It    250 [TRAIN] [dice_loss_14 ]: 0.0773048
# EndoVis17_Binary - It    250 [TRAIN] [ce_loss_15   ]: 0.0367146
# EndoVis17_Binary - It    250 [TRAIN] [dice_loss_15 ]: 0.0685283
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_250.pth.
# Current epoch: 252
# Current epoch: 253
# Current epoch: 254
# Current epoch: 255
# Current epoch: 256
# Current epoch: 257
# Current epoch: 258
# Current epoch: 259
# Current epoch: 260
# Current epoch: 261
# Current epoch: 262
# Current epoch: 263
# Current epoch: 264
# Current epoch: 265
# Current epoch: 266
# Current epoch: 267
# Current epoch: 268
# Current epoch: 269
# Current epoch: 270
# Current epoch: 271
# Current epoch: 272
# Current epoch: 273
# Current epoch: 274
# Current epoch: 275
# Current epoch: 276
# Current epoch: 277
# Current epoch: 278
# Current epoch: 279
# Current epoch: 280
# Current epoch: 281
# Current epoch: 282
# Current epoch: 283
# Current epoch: 284
# Current epoch: 285
# Current epoch: 286
# Current epoch: 287
# Current epoch: 288
# Current epoch: 289
# Current epoch: 290
# Current epoch: 291
# Current epoch: 292
# Current epoch: 293
# Current epoch: 294
# Current epoch: 295
# Current epoch: 296
# Current epoch: 297
# Current epoch: 298
# Current epoch: 299
# Current epoch: 300
# Current epoch: 301
# Changing skip to cur_skip=10
# 8 out of 18 videos accepted in data/endo17_binary/frames.
# Current epoch: 302
# EndoVis17_Binary - It    300 [TRAIN] [time         ]: 11.965721
# EndoVis17_Binary - It    300 [TRAIN] [total_loss   ]: 1.6963305
# EndoVis17_Binary - It    300 [TRAIN] [p            ]: 0.8716499
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_1    ]: 0.0409781
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_1  ]: 0.0750825
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_2    ]: 0.0440327
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_2  ]: 0.0787649
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_3    ]: 0.0389860
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_3  ]: 0.0654393
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_4    ]: 0.0368816
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_4  ]: 0.0649934
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_5    ]: 0.0438917
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_5  ]: 0.0679955
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_6    ]: 0.0396012
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_6  ]: 0.0709763
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_7    ]: 0.0420852
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_7  ]: 0.0634429
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_8    ]: 0.0399824
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_8  ]: 0.0744020
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_9    ]: 0.0425973
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_9  ]: 0.0663453
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_10   ]: 0.0418966
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_10 ]: 0.0695108
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_11   ]: 0.0388792
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_11 ]: 0.0713772
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_12   ]: 0.0469694
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_12 ]: 0.0809681
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_13   ]: 0.0420992
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_13 ]: 0.0694587
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_14   ]: 0.0440931
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_14 ]: 0.0836012
# EndoVis17_Binary - It    300 [TRAIN] [ce_loss_15   ]: 0.0387921
# EndoVis17_Binary - It    300 [TRAIN] [dice_loss_15 ]: 0.0722051
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_300.pth.
# Checkpoint saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_checkpoint_300.pth.
# Current epoch: 303
# Current epoch: 304
# Current epoch: 305
# Current epoch: 306
# Current epoch: 307
# Current epoch: 308
# Current epoch: 309
# Current epoch: 310
# Current epoch: 311
# Current epoch: 312
# Current epoch: 313
# Current epoch: 314
# Current epoch: 315
# Current epoch: 316
# Current epoch: 317
# Current epoch: 318
# Current epoch: 319
# Current epoch: 320
# Current epoch: 321
# Current epoch: 322
# Current epoch: 323
# Current epoch: 324
# Current epoch: 325
# Current epoch: 326
# Current epoch: 327
# Current epoch: 328
# Current epoch: 329
# Current epoch: 330
# Current epoch: 331
# Current epoch: 332
# Current epoch: 333
# Current epoch: 334
# Current epoch: 335
# Current epoch: 336
# Current epoch: 337
# Current epoch: 338
# Current epoch: 339
# Current epoch: 340
# Current epoch: 341
# Current epoch: 342
# Current epoch: 343
# Current epoch: 344
# Current epoch: 345
# Current epoch: 346
# Current epoch: 347
# Current epoch: 348
# Current epoch: 349
# Current epoch: 350
# Current epoch: 351
# Current epoch: 352
# EndoVis17_Binary - It    350 [TRAIN] [time         ]: 11.972150
# EndoVis17_Binary - It    350 [TRAIN] [total_loss   ]: 1.5852869
# EndoVis17_Binary - It    350 [TRAIN] [p            ]: 0.7866500
# EndoVis17_Binary - It    350 [TRAIN] [ce_loss_1    ]: 0.0456767
# EndoVis17_Binary - It    350 [TRAIN] [dice_loss_1  ]: 0.0684611
# EndoVis17_Binary - It    350 [TRAIN] [ce_loss_2    ]: 0.0418599
# EndoVis17_Binary - It    350 [TRAIN] [dice_loss_2  ]: 0.0682086
# EndoVis17_Binary - It    450 [TRAIN] [dice_loss_11 ]: 0.0602938
# EndoVis17_Binary - It    450 [TRAIN] [ce_loss_12   ]: 0.0469106
# EndoVis17_Binary - It    450 [TRAIN] [dice_loss_12 ]: 0.0618915
# EndoVis17_Binary - It    450 [TRAIN] [ce_loss_13   ]: 0.0484963
# EndoVis17_Binary - It    450 [TRAIN] [dice_loss_13 ]: 0.0623544
# EndoVis17_Binary - It    450 [TRAIN] [ce_loss_14   ]: 0.0476985
# EndoVis17_Binary - It    450 [TRAIN] [dice_loss_14 ]: 0.0706080
# EndoVis17_Binary - It    450 [TRAIN] [ce_loss_15   ]: 0.0533667
# EndoVis17_Binary - It    450 [TRAIN] [dice_loss_15 ]: 0.0646879
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_450.pth.
# Current epoch: 453
# Current epoch: 454
# Current epoch: 455
# Current epoch: 456
# Current epoch: 457
# Current epoch: 458
# Current epoch: 459
# Current epoch: 460
# Current epoch: 461
# Current epoch: 462
# Current epoch: 463
# Current epoch: 464
# Current epoch: 465
# Current epoch: 466
# Current epoch: 467
# Current epoch: 468
# Current epoch: 469
# Current epoch: 470
# Current epoch: 471
# Current epoch: 472
# Current epoch: 473
# Current epoch: 474
# Current epoch: 475
# Current epoch: 476
# Current epoch: 477
# Current epoch: 478
# Current epoch: 479
# Current epoch: 480
# Current epoch: 481
# Current epoch: 482
# Current epoch: 483
# Current epoch: 484
# Current epoch: 485
# Current epoch: 486
# Current epoch: 487
# Current epoch: 488
# Current epoch: 489
# Current epoch: 490
# Current epoch: 491
# Current epoch: 492
# Current epoch: 493
# Current epoch: 494
# Current epoch: 495
# Current epoch: 496
# Current epoch: 497
# Current epoch: 498
# Current epoch: 499
# Current epoch: 500
# Current epoch: 501
# Current epoch: 502
# EndoVis17_Binary - It    500 [TRAIN] [time         ]: 11.820195
# EndoVis17_Binary - It    500 [TRAIN] [total_loss   ]: 1.7829047
# EndoVis17_Binary - It    500 [TRAIN] [p            ]: 0.5316500
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_1    ]: 0.0633268
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_1  ]: 0.0682744
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_2    ]: 0.0544670
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_2  ]: 0.0636800
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_3    ]: 0.0585881
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_3  ]: 0.0703075
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_4    ]: 0.0536858
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_4  ]: 0.0615470
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_5    ]: 0.0563711
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_5  ]: 0.0719239
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_6    ]: 0.0608962
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_6  ]: 0.0626245
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_7    ]: 0.0521462
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_7  ]: 0.0608096
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_8    ]: 0.0534914
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_8  ]: 0.0544681
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_9    ]: 0.0563310
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_9  ]: 0.0644376
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_10   ]: 0.0548423
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_10 ]: 0.0632987
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_11   ]: 0.0531521
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_11 ]: 0.0722216
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_12   ]: 0.0496144
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_12 ]: 0.0539386
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_13   ]: 0.0548997
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_13 ]: 0.0637799
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_14   ]: 0.0497294
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_14 ]: 0.0610330
# EndoVis17_Binary - It    500 [TRAIN] [ce_loss_15   ]: 0.0539898
# EndoVis17_Binary - It    500 [TRAIN] [dice_loss_15 ]: 0.0650278
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_500.pth.
# Checkpoint saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_checkpoint_500.pth.
# Current epoch: 503
# Current epoch: 504
# Current epoch: 505
# Current epoch: 506
# Current epoch: 507
# Current epoch: 508
# Current epoch: 516
# Current epoch: 517
# Current epoch: 518
# Current epoch: 519
# Current epoch: 520
# Current epoch: 521
# Current epoch: 522
# Current epoch: 523
# Current epoch: 524
# Current epoch: 525
# Current epoch: 526
# Current epoch: 527
# Current epoch: 528
# Current epoch: 529
# Current epoch: 530
# Current epoch: 531
# Current epoch: 532
# Current epoch: 533
# Current epoch: 534
# Current epoch: 535
# Current epoch: 536
# Current epoch: 537
# Current epoch: 538
# Current epoch: 539
# Current epoch: 540
# Current epoch: 541
# Current epoch: 542
# Current epoch: 543
# Current epoch: 544
# Current epoch: 545
# Current epoch: 546
# Current epoch: 547
# Current epoch: 548
# Current epoch: 549
# Current epoch: 550
# Current epoch: 551
# Current epoch: 552
# EndoVis17_Binary - It    550 [TRAIN] [time         ]: 11.863623
# EndoVis17_Binary - It    550 [TRAIN] [total_loss   ]: 1.8602815
# EndoVis17_Binary - It    550 [TRAIN] [p            ]: 0.4466499
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_1    ]: 0.0628725
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_1  ]: 0.0645895
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_2    ]: 0.0626638
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_2  ]: 0.0691564
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_3    ]: 0.0638337
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_3  ]: 0.0582238
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_4    ]: 0.0646963
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_4  ]: 0.0652446
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_5    ]: 0.0632143
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_5  ]: 0.0603695
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_6    ]: 0.0638847
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_6  ]: 0.0577130
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_7    ]: 0.0634773
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_7  ]: 0.0654355
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_8    ]: 0.0651438
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_8  ]: 0.0643013
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_9    ]: 0.0583603
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_9  ]: 0.0534660
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_10   ]: 0.0576049
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_10 ]: 0.0579906
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_11   ]: 0.0602324
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_11 ]: 0.0554460
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_12   ]: 0.0606913
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_12 ]: 0.0549883
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_13   ]: 0.0629024
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_13 ]: 0.0681667
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_14   ]: 0.0603817
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_14 ]: 0.0634959
# EndoVis17_Binary - It    550 [TRAIN] [ce_loss_15   ]: 0.0669778
# EndoVis17_Binary - It    550 [TRAIN] [dice_loss_15 ]: 0.0647556
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_550.pth.
# Current epoch: 553
# Current epoch: 554
# Current epoch: 555
# Current epoch: 556
# Current epoch: 557
# Current epoch: 558
# Current epoch: 559
# Current epoch: 560
# Current epoch: 561
# Current epoch: 562
# Current epoch: 563
# Current epoch: 564
# Current epoch: 565
# Current epoch: 566
# Current epoch: 567
# Current epoch: 568
# Current epoch: 569
# Current epoch: 570
# Current epoch: 571
# Current epoch: 572
# Current epoch: 573
# Current epoch: 574
# Current epoch: 575
# Current epoch: 576
# Current epoch: 577
# Current epoch: 578
# Current epoch: 579
# Current epoch: 580
# Current epoch: 581
# Current epoch: 582
# Current epoch: 583
# Current epoch: 584
# Current epoch: 585
# Current epoch: 586
# Current epoch: 587
# Current epoch: 588
# Current epoch: 589
# Current epoch: 590
# EndoVis17_Binary - It    650 [TRAIN] [dice_loss_11 ]: 0.0696674
# EndoVis17_Binary - It    650 [TRAIN] [ce_loss_12   ]: 0.1001400
# EndoVis17_Binary - It    650 [TRAIN] [dice_loss_12 ]: 0.0640233
# EndoVis17_Binary - It    650 [TRAIN] [ce_loss_13   ]: 0.1054631
# EndoVis17_Binary - It    650 [TRAIN] [dice_loss_13 ]: 0.0613409
# EndoVis17_Binary - It    650 [TRAIN] [ce_loss_14   ]: 0.0950900
# EndoVis17_Binary - It    650 [TRAIN] [dice_loss_14 ]: 0.0640560
# EndoVis17_Binary - It    650 [TRAIN] [ce_loss_15   ]: 0.0880264
# EndoVis17_Binary - It    650 [TRAIN] [dice_loss_15 ]: 0.0645958
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_650.pth.
# Current epoch: 653
# Current epoch: 654
# Current epoch: 655
# Current epoch: 656
# Current epoch: 657
# Current epoch: 658
# Current epoch: 659
# Current epoch: 660
# Current epoch: 661
# Current epoch: 662
# Current epoch: 663
# Current epoch: 664
# Current epoch: 665
# Current epoch: 666
# Current epoch: 667
# Current epoch: 676
# Current epoch: 677
# Current epoch: 678
# Current epoch: 679
# Current epoch: 680
# Current epoch: 681
# Current epoch: 682
# Current epoch: 683
# Current epoch: 684
# Current epoch: 685
# Current epoch: 686
# Current epoch: 687
# Current epoch: 688
# Current epoch: 689
# Current epoch: 690
# Current epoch: 691
# Current epoch: 692
# Current epoch: 693
# Current epoch: 694
# Current epoch: 695
# Current epoch: 696
# Current epoch: 697
# Current epoch: 698
# Current epoch: 699
# Current epoch: 700
# Current epoch: 701
# Current epoch: 702
# EndoVis17_Binary - It    700 [TRAIN] [time         ]: 11.664908
# EndoVis17_Binary - It    700 [TRAIN] [total_loss   ]: 3.0733127
# EndoVis17_Binary - It    700 [TRAIN] [p            ]: 0.1916500
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_1    ]: 0.1347246
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_1  ]: 0.0686649
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_2    ]: 0.1351924
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_2  ]: 0.0636573
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_3    ]: 0.1466238
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_3  ]: 0.0708891
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_4    ]: 0.1344379
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_4  ]: 0.0640577
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_5    ]: 0.1383113
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_5  ]: 0.0651929
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_6    ]: 0.1338621
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_6  ]: 0.0666341
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_7    ]: 0.1562127
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_7  ]: 0.0675612
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_8    ]: 0.1339965
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_8  ]: 0.0637589
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_9    ]: 0.1297928
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_9  ]: 0.0625607
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_10   ]: 0.1370449
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_10 ]: 0.0663139
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_11   ]: 0.1452619
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_11 ]: 0.0652403
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_12   ]: 0.1424997
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_12 ]: 0.0680545
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_13   ]: 0.1334436
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_13 ]: 0.0726885
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_14   ]: 0.1369962
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_14 ]: 0.0670894
# EndoVis17_Binary - It    700 [TRAIN] [ce_loss_15   ]: 0.1331069
# EndoVis17_Binary - It    700 [TRAIN] [dice_loss_15 ]: 0.0694407
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_700.pth.
# Checkpoint saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_checkpoint_700.pth.
# Current epoch: 703
# Current epoch: 704
# Current epoch: 705
# Current epoch: 706
# Current epoch: 707
# Current epoch: 708
# Current epoch: 709
# Current epoch: 710
# Current epoch: 711
# Current epoch: 712
# Current epoch: 713
# Current epoch: 714
# Current epoch: 715
# Current epoch: 716
# Current epoch: 717
# Current epoch: 718
# Current epoch: 719
# Current epoch: 720
# Current epoch: 721
# Current epoch: 722
# Current epoch: 723
# Current epoch: 724
# Current epoch: 725
# Current epoch: 726
# Current epoch: 727
# Current epoch: 728
# Current epoch: 729
# Current epoch: 730
# Current epoch: 731
# Current epoch: 738
# Current epoch: 739
# Current epoch: 740
# Current epoch: 741
# Current epoch: 742
# Current epoch: 743
# Current epoch: 744
# Current epoch: 745
# Current epoch: 746
# Current epoch: 747
# Current epoch: 748
# Current epoch: 749
# Current epoch: 750
# Current epoch: 751
# Current epoch: 752
# EndoVis17_Binary - It    750 [TRAIN] [time         ]: 11.982715
# EndoVis17_Binary - It    750 [TRAIN] [total_loss   ]: 3.2717120
# EndoVis17_Binary - It    750 [TRAIN] [p            ]: 0.1500000
# EndoVis17_Binary - It    750 [TRAIN] [ce_loss_1    ]: 0.1638692
# EndoVis17_Binary - It    750 [TRAIN] [dice_loss_1  ]: 0.0620848
# EndoVis17_Binary - It    750 [TRAIN] [ce_loss_2    ]: 0.1533931
# EndoVis17_Binary - It    750 [TRAIN] [dice_loss_2  ]: 0.0634695
# EndoVis17_Binary - It    750 [TRAIN] [ce_loss_3    ]: 0.1499352
# Current epoch: 797
# Current epoch: 798
# Current epoch: 799
# Current epoch: 800
# Current epoch: 801
# Current epoch: 802
# EndoVis17_Binary - It    800 [TRAIN] [time         ]: 11.922219
# EndoVis17_Binary - It    800 [TRAIN] [total_loss   ]: 3.2637119
# EndoVis17_Binary - It    800 [TRAIN] [p            ]: 0.1500000
# EndoVis17_Binary - It    800 [TRAIN] [ce_loss_1    ]: 0.1596251
# EndoVis17_Binary - It    800 [TRAIN] [dice_loss_1  ]: 0.0589531
# EndoVis17_Binary - It    800 [TRAIN] [ce_loss_2    ]: 0.1566980
# EndoVis17_Binary - It    800 [TRAIN] [dice_loss_2  ]: 0.0548245
# EndoVis17_Binary - It    800 [TRAIN] [ce_loss_3    ]: 0.1486794
# EndoVis17_Binary - It    800 [TRAIN] [dice_loss_3  ]: 0.0616432
# EndoVis17_Binary - It    800 [TRAIN] [ce_loss_4    ]: 0.1526862
# EndoVis17_Binary - It    800 [TRAIN] [dice_loss_4  ]: 0.0555037
# EndoVis17_Binary - It    800 [TRAIN] [ce_loss_5    ]: 0.1490394
# EndoVis17_Binary - It    800 [TRAIN] [dice_loss_5  ]: 0.0656702
# EndoVis17_Binary - It    800 [TRAIN] [ce_loss_6    ]: 0.1474680
# EndoVis17_Binary - It    800 [TRAIN] [dice_loss_6  ]: 0.0627794
# EndoVis17_Binary - It    800 [TRAIN] [ce_loss_7    ]: 0.1557295
# EndoVis17_Binary - It    800 [TRAIN] [dice_loss_7  ]: 0.0614446
# EndoVis17_Binary - It    800 [TRAIN] [ce_loss_8    ]: 0.1493193
# ...
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_1  ]: 0.0512797
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_2    ]: 0.1239621
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_2  ]: 0.0540445
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_3    ]: 0.1165552
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_3  ]: 0.0494130
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_4    ]: 0.1305203
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_4  ]: 0.0465615
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_5    ]: 0.1269620
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_5  ]: 0.0474750
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_6    ]: 0.1356420
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_6  ]: 0.0475535
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_7    ]: 0.1227783
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_7  ]: 0.0486591
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_8    ]: 0.1247206
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_8  ]: 0.0471856
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_9    ]: 0.1275960
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_9  ]: 0.0498443
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_10   ]: 0.1182830
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_10 ]: 0.0459030
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_11   ]: 0.1230182
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_11 ]: 0.0499162
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_12   ]: 0.1289830
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_12 ]: 0.0471473
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_13   ]: 0.1202971
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_13 ]: 0.0511967
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_14   ]: 0.1276224
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_14 ]: 0.0547150
# EndoVis17_Binary - It   2750 [TRAIN] [ce_loss_15   ]: 0.1257868
# EndoVis17_Binary - It   2750 [TRAIN] [dice_loss_15 ]: 0.0485884
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_2750.pth.
# Current epoch: 2755
# Current epoch: 2756
# Current epoch: 2757
# Current epoch: 2758
# Current epoch: 2759
# Current epoch: 2760
# Current epoch: 2761
# Current epoch: 2762
# Current epoch: 2763
# Current epoch: 2764
# Current epoch: 2765
# Current epoch: 2766
# Current epoch: 2767
# Current epoch: 2768
# Current epoch: 2769
# Current epoch: 2770
# Current epoch: 2771
# Current epoch: 2772
# Current epoch: 2773
# Current epoch: 2774
# Current epoch: 2775
# Current epoch: 2776
# Current epoch: 2777
# Current epoch: 2778
# Current epoch: 2779
# Current epoch: 2780
# Current epoch: 2781
# Current epoch: 2782
# Current epoch: 2783
# Current epoch: 2784
# Current epoch: 2785
# Current epoch: 2786
# Current epoch: 2787
# Current epoch: 2788
# Current epoch: 2789
# Current epoch: 2790
# Current epoch: 2791
# Current epoch: 2792
# Current epoch: 2793
# Current epoch: 2794
# Current epoch: 2795
# Current epoch: 2796
# Current epoch: 2797
# Current epoch: 2798
# Current epoch: 2799
# Current epoch: 2800
# Current epoch: 2801
# Current epoch: 2802
# Current epoch: 2803
# Current epoch: 2804
# EndoVis17_Binary - It   2800 [TRAIN] [time         ]: 12.505270
# EndoVis17_Binary - It   2800 [TRAIN] [total_loss   ]: 2.5654530
# EndoVis17_Binary - It   2800 [TRAIN] [p            ]: 0.1500000
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_1    ]: 0.1166269
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_1  ]: 0.0523769
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_2    ]: 0.1202909
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_2  ]: 0.0490833
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_3    ]: 0.1220436
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_3  ]: 0.0485714
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_4    ]: 0.1356767
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_4  ]: 0.0524068
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_5    ]: 0.1211498
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_5  ]: 0.0484183
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_6    ]: 0.1388568
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_6  ]: 0.0466030
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_7    ]: 0.1251905
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_7  ]: 0.0512181
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_8    ]: 0.1203804
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_8  ]: 0.0437905
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_9    ]: 0.1250204
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_9  ]: 0.0457218
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_10   ]: 0.1171890
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_10 ]: 0.0432491
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_11   ]: 0.1171540
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_11 ]: 0.0497573
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_12   ]: 0.1147777
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_12 ]: 0.0470936
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_13   ]: 0.1177911
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_13 ]: 0.0470439
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_14   ]: 0.1203062
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_14 ]: 0.0511894
# EndoVis17_Binary - It   2800 [TRAIN] [ce_loss_15   ]: 0.1300215
# EndoVis17_Binary - It   2800 [TRAIN] [dice_loss_15 ]: 0.0464523
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_2800.pth.
# Checkpoint saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_checkpoint_2800.pth.
# Current epoch: 2805
# Current epoch: 2806
# Current epoch: 2807
# Current epoch: 2808
# Current epoch: 2809
# Current epoch: 2810
# Current epoch: 2811
# Current epoch: 2812
# Current epoch: 2813
# Current epoch: 2814
# Current epoch: 2815
# Current epoch: 2816
# Current epoch: 2817
# Current epoch: 2818
# Current epoch: 2819
# Current epoch: 2820
# Current epoch: 2821
# Current epoch: 2822
# Current epoch: 2823
# Current epoch: 2824
# Current epoch: 2825
# Current epoch: 2826
# Current epoch: 2827
# Current epoch: 2828
# Current epoch: 2829
# Current epoch: 2830
# Current epoch: 2831
# Current epoch: 2832
# Current epoch: 2833
# Current epoch: 2834
# Current epoch: 2835
# Current epoch: 2836
# Current epoch: 2837
# Current epoch: 2838
# Current epoch: 2839
# Current epoch: 2840
# Current epoch: 2841
# Current epoch: 2842
# Current epoch: 2843
# Current epoch: 2844
# Current epoch: 2845
# Current epoch: 2846
# Current epoch: 2847
# Current epoch: 2848
# Current epoch: 2849
# Current epoch: 2850
# Current epoch: 2851
# Current epoch: 2852
# Current epoch: 2853
# Current epoch: 2854
# EndoVis17_Binary - It   2850 [TRAIN] [time         ]: 12.712141
# EndoVis17_Binary - It   2850 [TRAIN] [total_loss   ]: 2.5372824
# EndoVis17_Binary - It   2850 [TRAIN] [p            ]: 0.1500000
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_1    ]: 0.1221207
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_1  ]: 0.0463596
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_2    ]: 0.1214471
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_2  ]: 0.0466093
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_3    ]: 0.1156342
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_3  ]: 0.0454180
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_4    ]: 0.1173208
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_4  ]: 0.0457251
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_5    ]: 0.1258177
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_5  ]: 0.0463202
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_6    ]: 0.1207848
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_6  ]: 0.0443590
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_7    ]: 0.1204241
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_7  ]: 0.0447996
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_8    ]: 0.1205329
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_8  ]: 0.0497413
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_9    ]: 0.1231075
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_9  ]: 0.0469752
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_10   ]: 0.1213270
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_10 ]: 0.0455359
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_11   ]: 0.1255739
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_11 ]: 0.0438964
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_12   ]: 0.1331257
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_12 ]: 0.0447532
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_13   ]: 0.1185211
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_13 ]: 0.0436282
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_14   ]: 0.1306275
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_14 ]: 0.0510567
# EndoVis17_Binary - It   2850 [TRAIN] [ce_loss_15   ]: 0.1278434
# EndoVis17_Binary - It   2850 [TRAIN] [dice_loss_15 ]: 0.0478952
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_2850.pth.
# Current epoch: 2855
# Current epoch: 2856
# Current epoch: 2857
# Current epoch: 2858
# Current epoch: 2859
# Current epoch: 2860
# Current epoch: 2861
# Current epoch: 2862
# Current epoch: 2863
# Current epoch: 2864
# Current epoch: 2865
# Current epoch: 2866
# Current epoch: 2867
# Current epoch: 2868
# Current epoch: 2869
# Current epoch: 2870
# Current epoch: 2871
# Current epoch: 2872
# Current epoch: 2873
# Current epoch: 2874
# Current epoch: 2875
# Current epoch: 2876
# Current epoch: 2877
# Current epoch: 2878
# Current epoch: 2879
# Current epoch: 2880
# Current epoch: 2881
# Current epoch: 2882
# Current epoch: 2883
# Current epoch: 2884
# Current epoch: 2885
# Current epoch: 2886
# Current epoch: 2887
# Current epoch: 2888
# Current epoch: 2889
# Current epoch: 2890
# Current epoch: 2891
# Current epoch: 2892
# Current epoch: 2893
# Current epoch: 2894
# Current epoch: 2895
# Current epoch: 2896
# Current epoch: 2897
# Current epoch: 2898
# Current epoch: 2899
# Current epoch: 2900
# Current epoch: 2901
# Current epoch: 2902
# Current epoch: 2903
# Current epoch: 2904
# EndoVis17_Binary - It   2900 [TRAIN] [time         ]: 12.773185
# EndoVis17_Binary - It   2900 [TRAIN] [total_loss   ]: 2.5755684
# EndoVis17_Binary - It   2900 [TRAIN] [p            ]: 0.1500000
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_1    ]: 0.1215736
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_1  ]: 0.0455721
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_2    ]: 0.1218536
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_2  ]: 0.0511579
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_3    ]: 0.1177879
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_3  ]: 0.0488876
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_4    ]: 0.1269718
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_4  ]: 0.0496260
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_5    ]: 0.1144746
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_5  ]: 0.0468162
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_6    ]: 0.1233674
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_6  ]: 0.0465569
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_7    ]: 0.1227123
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_7  ]: 0.0465646
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_8    ]: 0.1222613
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_8  ]: 0.0465636
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_9    ]: 0.1192900
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_9  ]: 0.0460952
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_10   ]: 0.1333780
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_10 ]: 0.0470063
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_11   ]: 0.1152304
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_11 ]: 0.0497159
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_12   ]: 0.1363228
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_12 ]: 0.0532630
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_13   ]: 0.1236119
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_13 ]: 0.0538940
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_14   ]: 0.1158721
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_14 ]: 0.0515441
# EndoVis17_Binary - It   2900 [TRAIN] [ce_loss_15   ]: 0.1276745
# EndoVis17_Binary - It   2900 [TRAIN] [dice_loss_15 ]: 0.0499214
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_2900.pth.
# Checkpoint saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_checkpoint_2900.pth.
# Current epoch: 2905
# Current epoch: 2906
# Current epoch: 2907
# Current epoch: 2908
# Current epoch: 2909
# Current epoch: 2910
# Current epoch: 2911
# Current epoch: 2912
# Current epoch: 2913
# Current epoch: 2914
# Current epoch: 2915
# Current epoch: 2916
# Current epoch: 2917
# Current epoch: 2918
# Current epoch: 2919
# Current epoch: 2920
# Current epoch: 2921
# Current epoch: 2922
# Current epoch: 2923
# Current epoch: 2924
# Current epoch: 2925
# Current epoch: 2926
# Current epoch: 2927
# Current epoch: 2928
# Current epoch: 2929
# Current epoch: 2930
# Current epoch: 2931
# Current epoch: 2932
# Current epoch: 2933
# Current epoch: 2934
# Current epoch: 2935
# Current epoch: 2936
# Current epoch: 2937
# Current epoch: 2938
# Current epoch: 2939
# Current epoch: 2940
# Current epoch: 2941
# Current epoch: 2942
# Current epoch: 2943
# Current epoch: 2944
# Current epoch: 2945
# Current epoch: 2946
# Current epoch: 2947
# Current epoch: 2948
# Current epoch: 2949
# Current epoch: 2950
# Current epoch: 2951
# Current epoch: 2952
# Current epoch: 2953
# Current epoch: 2954
# EndoVis17_Binary - It   2950 [TRAIN] [time         ]: 12.605245
# EndoVis17_Binary - It   2950 [TRAIN] [total_loss   ]: 2.5242824
# EndoVis17_Binary - It   2950 [TRAIN] [p            ]: 0.1500000
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_1    ]: 0.1238036
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_1  ]: 0.0544642
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_2    ]: 0.1230116
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_2  ]: 0.0476017
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_3    ]: 0.1149413
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_3  ]: 0.0466171
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_4    ]: 0.1140827
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_4  ]: 0.0446893
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_5    ]: 0.1194548
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_5  ]: 0.0441692
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_6    ]: 0.1200698
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_6  ]: 0.0469636
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_7    ]: 0.1232787
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_7  ]: 0.0478583
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_8    ]: 0.1207444
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_8  ]: 0.0513278
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_9    ]: 0.1168596
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_9  ]: 0.0549520
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_10   ]: 0.1214707
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_10 ]: 0.0469802
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_11   ]: 0.1247749
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_11 ]: 0.0495719
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_12   ]: 0.1153912
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_12 ]: 0.0454192
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_13   ]: 0.1207832
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_13 ]: 0.0455687
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_14   ]: 0.1293691
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_14 ]: 0.0450149
# EndoVis17_Binary - It   2950 [TRAIN] [ce_loss_15   ]: 0.1174506
# EndoVis17_Binary - It   2950 [TRAIN] [dice_loss_15 ]: 0.0475968
# Network saved to saves/Nov15_20.28.13_EndoVis17_Binary/Nov15_20.28.13_EndoVis17_Binary_2950.pth.
# Current epoch: 2955
# Current epoch: 2956
# Current epoch: 2957
# Current epoch: 2958
# Current epoch: 2959
# Current epoch: 2960
# Current epoch: 2961
# Current epoch: 2962
# Current epoch: 2963
# Current epoch: 2964
# Current epoch: 2965
# Current epoch: 2966
# Current epoch: 2967
# Current epoch: 2968
# Current epoch: 2969
# Current epoch: 2970
# Current epoch: 2971
# Current epoch: 2972
# Current epoch: 2973
# Current epoch: 2974
# Current epoch: 2975
# Current epoch: 2976
# Current epoch: 2977
# Current epoch: 2978
# Current epoch: 2979
# Current epoch: 2980
# Current epoch: 2981
# Current epoch: 2982
# Current epoch: 2983
# Current epoch: 2984
# Current epoch: 2985
# Current epoch: 2986
# Current epoch: 2987
# Current epoch: 2988
# Current epoch: 2989
# Current epoch: 2990
# Current epoch: 2991
# Current epoch: 2992
# Current epoch: 2993
# Current epoch: 2994
# Current epoch: 2995
# Current epoch: 2996
# Current epoch: 2997
# Current epoch: 2998
# Current epoch: 2999
# Current epoch: 3000
# Current epoch: 3001
# Current epoch: 3002
# Current epoch: 3003

# %%
print("Training Completed")
# Out:
# Training Completed
